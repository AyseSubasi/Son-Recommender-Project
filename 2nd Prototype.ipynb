# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import config
import random

# %%
df=pd.read_csv("./kmeans.csv")
hot_songs=pd.read_csv("./df.csv")

# %%
df
# Out:
#       Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0              0         0.533   0.638    4    -7.130     1       0.0341
# 1              1         0.612   0.924    9    -3.877     1       0.0316
# 2              2         0.741   0.727    5    -4.174     0       0.1510
# 3              3         0.597   0.463    7    -5.528     1       0.0371
# 4              4         0.743   0.766    0    -6.375     1       0.0265
# ...          ...           ...     ...  ...       ...   ...          ...
# 4932        4932         0.619   0.917    5    -2.582     1       0.0507
# 4933        4933         0.497   0.590    2   -11.203     0       0.0296
# 4934        4934         0.532   0.708   10    -9.162     1       0.0339
# 4935        4935         0.502   0.750   10    -7.603     1       0.0312
# 4936        4936         0.538   0.604    2   -10.936     0       0.0262
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0           0.2020          0.000000    0.0729    0.937  156.663       153760
# 1           0.1590          0.000043    0.1030    0.960  115.953       295987
# 2           0.0205          0.000000    0.2640    0.370  130.023       263360
# 3           0.8240          0.000000    0.1070    0.227  115.837       229840
# 4           0.0873          0.000000    0.5090    0.610  127.960       289133
# ...            ...               ...       ...      ...      ...          ...
# 4932        0.0233          0.000012    0.0986    0.552  131.002       200347
# 4933        0.1390          0.000007    0.3780    0.969  142.027       137480
# 4934        0.5510          0.000000    0.3180    0.887  138.490       177067
# 4935        0.0256          0.000011    0.1880    0.904  128.099       146760
# 4936        0.5570          0.000000    0.1620    0.373  102.839       223160
#
#       time_signature  popularity  cluster
# 0                  4          53        3
# 1                  4          52        9
# 2                  4           0        0
# 3                  4           0        1
# 4                  4          71        9
# ...              ...         ...      ...
# 4932               4          51        9
# 4933               4          49        4
# 4934               4          25        6
# 4935               4           5        5
# 4936               4          52        4
#
# [4937 rows x 16 columns]

# %%
#drop unnamed
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
hot_songs.drop(columns=["Unnamed: 0"],inplace=True)

# %%
#rename columns:
hot_songs = hot_songs.rename(columns={'Rank': 'rank', 'Song Title': 'title', "Song Artist": "artist", "Year": "year", "Genre": "genre", "Decade": "decade"})

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
hot_songs
# Out:
#      rank                              title                         artist  \
# 0      57                               1999                         Prince
# 1      20  (Everything I Do) I Do It For You                    Bryan Adams
# 2      46      (I Can't Get No) Satisfaction                 Rolling Stones
# 3      15     (I've Had) The Time Of My Life  Bill Medley & Jennifer Warnes
# 4      47        (Let Me Be Your) Teddy Bear                  Elvis Presley
# ..    ...                                ...                            ...
# 595    93             You're The Inspiration                        Chicago
# 596    34         You're The One That I Want  John Travolta & Olivia Newton
# 597    68    You've Lost That Lovin' Feelin'             Righteous Brothers
# 598    53                          Your Love                       Outfield
# 599    37                          Your Song                     Elton John
#
#      year    genre  decade
# 0    1983  Popular    1980
# 1    1991   Ballad    1990
# 2    1965   Oldies    1960
# 3    1987   Ballad    1980
# 4    1957   Oldies    1950
# ..    ...      ...     ...
# 595  1984   Ballad    1980
# 596  1978  Popular    1970
# 597  1964   Oldies    1960
# 598  1985  Popular    1980
# 599  1971   Ballad    1970
#
# [600 rows x 6 columns]

# %%
#random choice
recommendations= random.choice(hot_songs.title)

# %%
def recommend_plus_artist():
    
    ask_song=input("Welcome to Gnoosic! Tell me your favorite song: ").lower().title()
#  ask_artist=input("Which artist?") # input artist
    
    if len(ask_song) == 0: #if input is empty ask again
        ask_song=input("Still waiting for your song: ").lower().title()
#typos:

#if same name of song then ask for artist:
        
    if ask_song in list(hot_songs["title"]):
            return "Good choice! What do you think about:"  + " " + recommendations
        
        #if music doenst exist-> ask for artist
        

    if ask_song not in list (hot_songs["title"]):
        ask_artist=input("Couldn't find a match. Maybe I can help you if you tell me the artist? Artist:").lower().title()
        
    if ask_artist in list(hot_songs["artist"]):
        return "Good choice! What do you think about:"  + " " + recommendations
    
    else:
        return "Sorry there is no hot music for you"

# %%
recommend_plus_artist()
# Out:
# Welcome to Gnoosic! Tell me your favorite song: blbal
# Couldn't find a match. Maybe I can help you if you tell me the artist? Artist:prince
# "Good choice! What do you think about: Ain't No Mountain High Enough"
