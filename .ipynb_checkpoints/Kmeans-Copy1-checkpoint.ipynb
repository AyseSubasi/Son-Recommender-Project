# %%
import pandas as pd
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np
import matplotlib.pyplot as plt
import pickle

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import config
import random

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
m_df=pd.read_csv("./merged_df.csv")

# %%
df=pd.read_csv("./kmeans.csv")
hot_songs=pd.read_csv("./df.csv")

# %%
m_df.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.533   0.638    4    -7.130     1       0.0341
# 1           1         0.612   0.924    9    -3.877     1       0.0316
# 2           2         0.741   0.727    5    -4.174     0       0.1510
# 3           3         0.597   0.463    7    -5.528     1       0.0371
# 4           4         0.743   0.766    0    -6.375     1       0.0265
#
#    acousticness  instrumentalness  liveness  ...            type  \
# 0        0.2020          0.000000    0.0729  ...  audio_features
# 1        0.1590          0.000043    0.1030  ...  audio_features
# 2        0.0205          0.000000    0.2640  ...  audio_features
# 3        0.8240          0.000000    0.1070  ...  audio_features
# 4        0.0873          0.000000    0.5090  ...  audio_features
#
#                        id                                   uri  \
# 0  3ohLnESFgYACPMCkoTOzqE  spotify:track:3ohLnESFgYACPMCkoTOzqE
# ...

# %%
#drop unnamed column
m_df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
m_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.533   0.638    4    -7.130     1       0.0341        0.2020
# 1         0.612   0.924    9    -3.877     1       0.0316        0.1590
# 2         0.741   0.727    5    -4.174     0       0.1510        0.0205
# 3         0.597   0.463    7    -5.528     1       0.0371        0.8240
# 4         0.743   0.766    0    -6.375     1       0.0265        0.0873
#
#    instrumentalness  liveness  valence  ...            type  \
# 0          0.000000    0.0729    0.937  ...  audio_features
# 1          0.000043    0.1030    0.960  ...  audio_features
# 2          0.000000    0.2640    0.370  ...  audio_features
# 3          0.000000    0.1070    0.227  ...  audio_features
# 4          0.000000    0.5090    0.610  ...  audio_features
#
#                        id                                   uri  \
# 0  3ohLnESFgYACPMCkoTOzqE  spotify:track:3ohLnESFgYACPMCkoTOzqE
# ...

# %% [markdown]
# ### scaling features

# %%
m_df.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   4937.000000  4937.000000  4937.000000  4937.000000  4937.000000
# mean       0.605546     0.598410     5.208224    -9.171596     0.733036
# std        0.152746     0.203118     3.555930     3.525859     0.442418
# min        0.156000     0.026400     0.000000   -23.954000     0.000000
# 25%        0.507000     0.452000     2.000000   -11.548000     0.000000
# 50%        0.618000     0.609000     5.000000    -8.794000     1.000000
# 75%        0.715000     0.757000     8.000000    -6.482000     1.000000
# max        0.988000     0.996000    11.000000    -1.040000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  4937.000000   4937.000000       4937.000000  4937.000000  4937.000000
# mean      0.061127      0.329579          0.032453     0.181293     0.639191
# std       0.063598      0.286095          0.136872     0.149510     0.238533
# ...

# %%
#get numercial features

X= m_df.select_dtypes(include=np.number)

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.533   0.638    4    -7.130     1       0.0341        0.2020
# 1         0.612   0.924    9    -3.877     1       0.0316        0.1590
# 2         0.741   0.727    5    -4.174     0       0.1510        0.0205
# 3         0.597   0.463    7    -5.528     1       0.0371        0.8240
# 4         0.743   0.766    0    -6.375     1       0.0265        0.0873
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000000    0.0729    0.937  156.663       153760               4
# 1          0.000043    0.1030    0.960  115.953       295987               4
# 2          0.000000    0.2640    0.370  130.023       263360               4
# 3          0.000000    0.1070    0.227  115.837       229840               4
# 4          0.000000    0.5090    0.610  127.960       289133               4
#
#    popularity
# 0          53
# 1          52
# 2           0
# ...

# %%
X_scaled_df.describe() # to check if features have the same weight
# Out:
#        danceability        energy           key      loudness          mode  \
# count  4.937000e+03  4.937000e+03  4.937000e+03  4.937000e+03  4.937000e+03
# mean   1.885265e-16  5.416891e-17 -1.375354e-16  1.087960e-16  1.073208e-15
# std    1.000101e+00  1.000101e+00  1.000101e+00  1.000101e+00  1.000101e+00
# min   -2.943393e+00 -2.816437e+00 -1.464807e+00 -4.192992e+00 -1.657054e+00
# 25%   -6.452293e-01 -7.208881e-01 -9.023092e-01 -6.740611e-01 -1.657054e+00
# 50%    8.154039e-02  5.214112e-02 -5.856265e-02  1.071041e-01  6.034807e-01
# 75%    7.166454e-01  7.808565e-01  7.851839e-01  7.628972e-01  6.034807e-01
# max    2.504106e+00  1.957633e+00  1.628930e+00  2.306507e+00  6.034807e-01
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  4.937000e+03  4.937000e+03      4.937000e+03  4.937000e+03
# mean  -6.622659e-17  1.237954e-16      4.230125e-16  2.544495e-17
# std    1.000101e+00  1.000101e+00      1.000101e+00  1.000101e+00
# ...

# %% [markdown]
# ### Clustering

# %%
kmeans = KMeans(n_clusters=12, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=12, random_state=1234)

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     627
# 1     476
# 2     485
# 3     357
# 4     360
# 5     475
# 6     598
# 7     232
# 8     148
# 9     683
# 10    264
# 11    232
# dtype: int64

# %%
# check which group was assigend 

X["cluster"] = clusters
X.head()
# Out:
# <ipython-input-14-99329742fc70>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["cluster"] = clusters
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.533   0.638    4    -7.130     1       0.0341        0.2020
# 1         0.612   0.924    9    -3.877     1       0.0316        0.1590
# 2         0.741   0.727    5    -4.174     0       0.1510        0.0205
# 3         0.597   0.463    7    -5.528     1       0.0371        0.8240
# 4         0.743   0.766    0    -6.375     1       0.0265        0.0873
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000000    0.0729    0.937  156.663       153760               4
# ...

# %% [markdown]
# ### playing with the parameters

# %%
kmeans.inertia_ # decided k=12
# Out:
# 36700.80715478159

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} neighbours! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 neighbours!
#
# Training a K-Means model with 3 neighbours!
#
# Training a K-Means model with 4 neighbours!
#
# Training a K-Means model with 5 neighbours!
#
# Training a K-Means model with 6 neighbours!
#
# Training a K-Means model with 7 neighbours!
#
# Training a K-Means model with 8 neighbours!
#
# Training a K-Means model with 9 neighbours!
#
# Training a K-Means model with 10 neighbours!
#
# Training a K-Means model with 11 neighbours!
#
# Training a K-Means model with 12 neighbours!
#
# Training a K-Means model with 13 neighbours!
#
# Training a K-Means model with 14 neighbours!
#
# Training a K-Means model with 15 neighbours!
#
# Training a K-Means model with 16 neighbours!
#
# Training a K-Means model with 17 neighbours!
#
# Training a K-Means model with 18 neighbours!
#
# Training a K-Means model with 19 neighbours!
#
# Training a K-Means model with 20 neighbours!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# elbow-> 8-9 checkin silouhette to decide..

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,random_state=1234)
    kmeans.fit(X_scaled_df)
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
#here is the optimal k=3 the results are dissapointed
#for us is the optimal k between 8-9 -> k=12

# %%
X.to_csv("./kmeans.csv")

# %%
hot_songs.head()
# Out:
#    Unnamed: 0  Rank                         Song Title  \
# 0           0    57                               1999
# 1           0    20  (Everything I Do) I Do It For You
# 2           0    46      (I Can't Get No) Satisfaction
# 3           0    15     (I've Had) The Time Of My Life
# 4           0    47        (Let Me Be Your) Teddy Bear
#
#                      Song Artist  Year    Genre  Decade
# 0                         Prince  1983  Popular    1980
# 1                    Bryan Adams  1991   Ballad    1990
# 2                 Rolling Stones  1965   Oldies    1960
# 3  Bill Medley & Jennifer Warnes  1987   Ballad    1980
# 4                  Elvis Presley  1957   Oldies    1950

# %%
hot_songs.drop(columns=["Unnamed: 0"],inplace=True)

# %%
#rename columns:
hot_songs = hot_songs.rename(columns={'Rank': 'rank', 'Song Title': 'title', "Song Artist": "artist", "Year": "year", "Genre": "genre", "Decade": "decade"})

# %%
def hot_recommender():
    ask_song = input("Tell us a song you like: ").title()
    if hot_songs['title'].str.contains(ask_song).any():
        print("Nice song! Do you know " + hot_songs.sample(n=1)["title"].item() + " by " + hot_songs.sample(n=1)["artist"].item() + "? I'm sure you will like it!")

    else:
        results = sp.search(q=ask_song, limit=1)
        user_id = results['tracks']['items'][0]['id']
        user_audio = sp.audio_features(tracks=user_id) # drop 'popularity it is in user_audio'
        new = pd.DataFrame(user_audio[0], index=[0])[X.drop(['cluster'], axis=1).columns]
        user_scaled = scaler.transform(new)
        user_cluster = kmeans.predict(user_scaled) # user input to clusters
        recommendation = df[df['cluster']==user_cluster[0]].sample(n=1)["title"].item()
#       artist = df[df['title']==recommendation]['artist']
        print("Nice song! Do you know " + recommendation.upper() + "I'm sure you will like it!")

# %%
hot_recommender()
# Out:
# Tell us a song you like: kkk
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-5ee1868d339f> in <module>
# ----> 1 hot_recommender()
#
# <ipython-input-23-13f2f0b1129e> in hot_recommender()
#       8         user_id = results['tracks']['items'][0]['id']
#       9         user_audio = sp.audio_features(tracks=user_id) # drop 'popularity it is in user_audio'
# ---> 10         new = pd.DataFrame(user_audio[0], index=[0])[X.drop(['cluster'], axis=1).columns]
#      11         user_scaled = scaler.transform(new)
#      12         user_cluster = kmeans.predict(user_scaled) # user input to clusters
#
# ~\AppData\Local\conda\conda\envs\DataEnv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# ...

# %%
ask_song = input("Tell us a song you like: ").title()
# Out:
# Tell us a song you like: yes

# %%
results = sp.search(q=ask_song, limit=1)
user_id = results['tracks']['items'][0]['id']

# %%
user_audio = sp.audio_features(tracks=user_id)

# %%
new = pd.DataFrame(user_audio[0], index=[0])[X.drop(['cluster'], axis=1).columns]
new.columns = new.columns.to_series().apply(lambda x: x.strip())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-2bf394cfde7c> in <module>
# ----> 1 new = pd.DataFrame(user_audio[0], index=[0])[X.drop(['cluster'], axis=1).columns]
#       2 new.columns = new.columns.to_series().apply(lambda x: x.strip())
#
# ~\AppData\Local\conda\conda\envs\DataEnv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~\AppData\Local\conda\conda\envs\DataEnv\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %%
X.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.533   0.638    4    -7.130     1       0.0341        0.2020
# 1         0.612   0.924    9    -3.877     1       0.0316        0.1590
# 2         0.741   0.727    5    -4.174     0       0.1510        0.0205
# 3         0.597   0.463    7    -5.528     1       0.0371        0.8240
# 4         0.743   0.766    0    -6.375     1       0.0265        0.0873
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000000    0.0729    0.937  156.663       153760               4
# 1          0.000043    0.1030    0.960  115.953       295987               4
# 2          0.000000    0.2640    0.370  130.023       263360               4
# 3          0.000000    0.1070    0.227  115.837       229840               4
# 4          0.000000    0.5090    0.610  127.960       289133               4
#
#    popularity  cluster
# 0          53        3
# ...

# %%
new.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-e6a263a4ba4b> in <module>
# ----> 1 new.head()
#
# NameError: name 'new' is not defined
